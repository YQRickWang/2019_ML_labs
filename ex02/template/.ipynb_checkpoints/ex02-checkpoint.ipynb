# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load the data

# %%
import datetime
from helpers import *

height, weight, gender = load_data(sub_sample=False, add_outlier=False)
x, mean_x, std_x = standardize(height)
y, tx = build_model_data(x, weight)

# %%
y.shape, tx.shape
# Out:
# ((10000,), (10000, 2))

# %% [markdown]
# # 1 Computing the Cost Function

# %% [markdown]
# Fill in the `compute_loss` function below:
# <a id='compute_loss'></a>

# %%
def compute_loss(y, tx, w):
    """Calculate the loss.

    You can calculate the loss using mse or mae.
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    losses = np.dot(np.transpose(y-np.dot(tx,w)),y-np.dot(tx,w))*(1/(2*y.shape[0]))
    return losses
    # TODO: compute loss by MSE
    # ***************************************************

# %%
compute_loss(y,tx,w=[1,2])
# Out:
# 2694.4833658870843

# %% [markdown]
# # 2 Grid Search
#
# Fill in the function `grid_search()` below:

# %%
def grid_search(y, tx, w0, w1):
    """Algorithm for grid search."""
    losses = np.zeros((len(w0), len(w1)))
    # ***************************************************
    # INSERT YOUR CODE HERE
    for i in range(len(w0)):
        for j in range (len(w1)):
            losses[i,j] =compute_loss(y,tx,[w0[i],w1[j]])
        
    # TODO: compute loss for each combination of w0 and w1.
    # ***************************************************
    return losses

# %% [markdown]
# Let us play with the grid search demo now!

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=200)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=15.610085652488797, w0*=73.36683417085428, w1*=12.8140703517588, execution time=2.244 seconds

# %% [markdown]
# # 3 Gradient Descent

# %% [markdown]
# Again, please fill in the functions `compute_gradient` below:

# %%
def compute_gradient(y, tx, w):
    """Compute the gradient."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    gradient = -1/(1.0*(y.shape[0]))*np.dot(np.transpose(tx),y-np.dot(tx,w))
    return gradient
    # TODO: compute gradient and error vector
    # ***************************************************

# %%
compute_gradient(y,tx,[100,2])
# Out:
# array([ 26.706078  , -11.47971243])

# %%
compute_gradient(y,tx,[50,10])
# Out:
# array([-23.293922  ,  -3.47971243])

# %% [markdown]
# Please fill in the functions `gradient_descent` below:

# %%
def gradient_descent(y, tx, initial_w, max_iters, gamma):
    """Gradient descent algorithm."""
    # Define parameters to store w and loss
    ws = [initial_w]
    losses = []
    w = initial_w
    for n_iter in range(max_iters):
        # ***************************************************
        # INSERT YOUR CODE HERE
        loss = compute_loss(y,tx,w)
        gradient = compute_gradient(y,tx,w)
        # TODO: compute gradient and loss
        # ***************************************************

        # ***************************************************
        # INSERT YOUR CODE HERE
        w = w - gamma*gradient
        # TODO: update w by gradient
        # ***************************************************

        # store w and loss
        ws.append(w)
        losses.append(loss)
        print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))

    return losses, ws

# %% [markdown]
# Test your gradient descent function through gradient descent demo shown below:

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.1

# Initialization
w_initial = np.array([100, 10])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=378.0473881987589, w0=97.32939220021052, w1=10.347971243498908
# Gradient Descent(1/49): loss=309.1417031360723, w0=94.92584518039999, w1=10.661145362647924
# Gradient Descent(2/49): loss=253.32809823529618, w0=92.7626528625705, w1=10.943002069882038
# Gradient Descent(3/49): loss=208.11907826566738, w0=90.81577977652397, w1=11.196673106392742
# Gradient Descent(4/49): loss=171.49977209026807, w0=89.06359399908209, w1=11.424977039252374
# Gradient Descent(5/49): loss=141.8381340881947, w0=87.4866267993844, w1=11.630450578826043
# Gradient Descent(6/49): loss=117.81220730651525, w0=86.06735631965648, w1=11.815376764442345
# Gradient Descent(7/49): loss=98.35120661335503, w0=84.79001288790136, w1=11.981810331497018
# Gradient Descent(8/49): loss=82.58779605189518, w0=83.64040379932173, w1=12.131600541846222
# Gradient Descent(9/49): loss=69.81943349711263, w0=82.60575561960007, w1=12.266411731160506
# Gradient Descent(10/49): loss=59.47705982773877, w0=81.67457225785058, w1=12.387741801543362
# Gradient Descent(11/49): loss=51.099737155545974, w0=80.83650723227605, w1=12.496938864887932
# Gradient Descent(12/49): loss=44.31410579106986, w0=80.08224870925896, w1=12.595216221898044
# Gradient Descent(13/49): loss=38.817744385844165, w0=79.40341603854358, w1=12.683665843207145
# Gradient Descent(14/49): loss=34.36569164761134, w0=78.79246663489974, w1=12.763270502385335
# Gradient Descent(15/49): loss=30.75952892964275, w0=78.24261217162028, w1=12.834914695645708
# Gradient Descent(16/49): loss=27.838537128088195, w0=77.74774315466877, w1=12.899394469580042
# Gradient Descent(17/49): loss=25.47253376882901, w0=77.3023610394124, w1=12.957426266120942
# Gradient Descent(18/49): loss=23.556071047829057, w0=76.90151713568169, w1=13.009654883007753
# Gradient Descent(19/49): loss=22.003736243819137, w0=76.54075762232404, w1=13.056660638205884
# Gradient Descent(20/49): loss=20.74634505257109, w0=76.21607406030215, w1=13.098965817884201
# Gradient Descent(21/49): loss=19.727858187660157, w0=75.92385885448245, w1=13.137040479594686
# Gradient Descent(22/49): loss=18.902883827082295, w0=75.66086516924472, w1=13.171307675134123
# Gradient Descent(23/49): loss=18.234654595014234, w0=75.42417085253076, w1=13.202148151119616
# Gradient Descent(24/49): loss=17.69338891703912, w0=75.2111459674882, w1=13.22990457950656
# Gradient Descent(25/49): loss=17.254963717879274, w0=75.01942357094991, w1=13.25488536505481
# Gradient Descent(26/49): loss=16.89983930655981, w0=74.84687341406544, w1=13.277368072048233
# Gradient Descent(27/49): loss=16.612188533391034, w0=74.69157827286942, w1=13.297602508342315
# Gradient Descent(28/49): loss=16.37919140712433, w0=74.55181264579299, w1=13.31581350100699
# Gradient Descent(29/49): loss=16.190463734848286, w0=74.42602358142422, w1=13.332203394405195
# Gradient Descent(30/49): loss=16.037594320304706, w0=74.31281342349232, w1=13.34695429846358
# Gradient Descent(31/49): loss=15.913770094524395, w0=74.2109242813536, w1=13.360230112116126
# Gradient Descent(32/49): loss=15.813472471642344, w0=74.11922405342875, w1=13.372178344403418
# Gradient Descent(33/49): loss=15.73223139710788, w0=74.0366938482964, w1=13.38293175346198
# Gradient Descent(34/49): loss=15.666426126734965, w0=73.96241666367727, w1=13.392609821614688
# Gradient Descent(35/49): loss=15.61312385773291, w0=73.89556719752007, w1=13.401320082952124
# Gradient Descent(36/49): loss=15.569949019841243, w0=73.83540267797858, w1=13.409159318155815
# Gradient Descent(37/49): loss=15.534977401148995, w0=73.78125461039124, w1=13.41621462983914
# Gradient Descent(38/49): loss=15.506650390008273, w0=73.73252134956263, w1=13.42256441035413
# Gradient Descent(39/49): loss=15.483705510984283, w0=73.68866141481689, w1=13.428279212817623
# Gradient Descent(40/49): loss=15.465120158974857, w0=73.64918747354572, w1=13.433422535034765
# Gradient Descent(41/49): loss=15.450066023847222, w0=73.61366092640166, w1=13.438051525030193
# Gradient Descent(42/49): loss=15.437872174393831, w0=73.58168703397202, w1=13.44221761602608
# Gradient Descent(43/49): loss=15.427995156336591, w0=73.55291053078534, w1=13.445967097922376
# Gradient Descent(44/49): loss=15.419994771710225, w0=73.52701167791733, w1=13.449341631629043
# Gradient Descent(45/49): loss=15.413514460162872, w0=73.50370271033611, w1=13.452378711965043
# Gradient Descent(46/49): loss=15.40826540780951, w0=73.48272463951302, w1=13.455112084267444
# Gradient Descent(47/49): loss=15.40401367540329, w0=73.46384437577224, w1=13.457572119339606
# Gradient Descent(48/49): loss=15.40056977215425, w0=73.44685213840553, w1=13.45978615090455
# Gradient Descent(49/49): loss=15.397780210522528, w0=73.4315591247755, w1=13.461778779313
# Gradient Descent: execution time=0.016 seconds

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # 4 Stochastic gradient descent

# %%
def compute_stoch_gradient(y, tx, w):
    """Compute a stochastic gradient from just few examples n and their corresponding y_n labels."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    gradient = -1.0/(len(tx))*np.dot(np.transpose(tx),y-np.dot(tx,w))
    return gradient
    # TODO: implement stochastic gradient computation.It's same as the gradient descent.
    # ***************************************************



def stochastic_gradient_descent(
        y, tx, initial_w, batch_size, max_iters, gamma):
    """Stochastic gradient descent algorithm."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    ws = [initial_w]
    losses = []
    w = initial_w
    
    for n_iter in range(max_iters):
        for minibatch_y,minibatch_tx in batch_iter(y,tx,batch_size,num_batches =1 , shuffle = True):
            loss = compute_loss(y,tx,w)
            gradient = compute_stoch_gradient(minibatch_y,minibatch_tx,w)
        
            w = w - gamma*gradient
            #store w and loss
            ws.append(w)
            losses.append(loss)
            print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
    # TODO: implement stochastic gradient descent.
    # ***************************************************

    return losses, ws

# %%
# from stochastic_gradient_descent import *

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7
batch_size = 20

# Initialization
w_initial = np.array([0, 0])

# Start SGD.
start_time = datetime.datetime.now()
sgd_losses, sgd_ws = stochastic_gradient_descent(
    y, tx, w_initial, batch_size, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=2792.236712759167, w0=48.009815263337096, w1=-6.915268711978604
# Gradient Descent(1/49): loss=543.0065426501209, w0=68.69420777110864, w1=15.700088836749615
# Gradient Descent(2/49): loss=28.42960905499312, w0=70.66592607856123, w1=14.139267050488089
# Gradient Descent(3/49): loss=19.056575301324287, w0=72.96877084886228, w1=14.513178722607757
# Gradient Descent(4/49): loss=15.972775788879197, w0=72.91277744615867, w1=14.049958501312574
# Gradient Descent(5/49): loss=15.621113743171964, w0=73.32287057354803, w1=15.226717207937929
# Gradient Descent(6/49): loss=16.912319717076777, w0=71.94416583058309, w1=14.662174666838169
# Gradient Descent(7/49): loss=16.995917194985203, w0=73.24899046523579, w1=14.349011995759195
# Gradient Descent(8/49): loss=15.76473815350971, w0=72.72644721784712, w1=12.860027991157805
# Gradient Descent(9/49): loss=15.73890608917699, w0=73.71398078930817, w1=11.132518200752111
# Gradient Descent(10/49): loss=18.228772947800184, w0=70.84683459064563, w1=12.033544429022323
# Gradient Descent(11/49): loss=19.425707219232212, w0=71.79840520997858, w1=13.228122013777623
# Gradient Descent(12/49): loss=16.5358219766184, w0=73.03146883374266, w1=13.458621003358225
# Gradient Descent(13/49): loss=15.420551125865282, w0=72.84425677085835, w1=13.321755946812479
# Gradient Descent(14/49): loss=15.499462405004074, w0=72.95858934353598, w1=12.60058111878878
# Gradient Descent(15/49): loss=15.828547800342958, w0=75.07787241580087, w1=13.933706577058773
# Gradient Descent(16/49): loss=17.080182748608703, w0=73.43270997206538, w1=14.64321029475669
# Gradient Descent(17/49): loss=16.072382553974176, w0=73.33152597513252, w1=13.743754275763457
# Gradient Descent(18/49): loss=15.421453945062892, w0=73.50075404550056, w1=12.907399129628823
# Gradient Descent(19/49): loss=15.571048875663127, w0=72.46944786698384, w1=13.360465959395357
# Gradient Descent(20/49): loss=15.732876529542203, w0=75.2345759397777, w1=13.745387561977132
# Gradient Descent(21/49): loss=17.304248358281374, w0=73.82017346363943, w1=12.687730549822408
# Gradient Descent(22/49): loss=15.837975822428918, w0=73.9308045778439, w1=12.745525669083412
# Gradient Descent(23/49): loss=15.858212680084678, w0=73.83257055565201, w1=12.540581415054836
# Gradient Descent(24/49): loss=15.97194253724978, w0=73.42046266369826, w1=13.798157717127468
# Gradient Descent(25/49): loss=15.444597837205714, w0=73.33376014371485, w1=14.804915421542582
# Gradient Descent(26/49): loss=16.264762885378058, w0=72.9530155802912, w1=13.989308035800937
# Gradient Descent(27/49): loss=15.57384030122983, w0=73.42423046013293, w1=13.723928780715434
# Gradient Descent(28/49): loss=15.424198827706162, w0=72.80821642760986, w1=14.165024156384556
# Gradient Descent(29/49): loss=15.738668899118354, w0=73.73644638995447, w1=14.288796436584414
# Gradient Descent(30/49): loss=15.811110246568873, w0=72.4245753618718, w1=14.186511123736148
# Gradient Descent(31/49): loss=16.013551852479253, w0=72.0859766872628, w1=13.513664996368233
# Gradient Descent(32/49): loss=16.116030198866344, w0=70.6777764870401, w1=12.960352686859533
# Gradient Descent(33/49): loss=18.942863820815553, w0=72.64604873497842, w1=13.85354406031568
# Gradient Descent(34/49): loss=15.66563279600533, w0=72.52510291742534, w1=13.727497311875013
# Gradient Descent(35/49): loss=15.712127933920076, w0=73.86642437215957, w1=11.872466156568768
# Gradient Descent(36/49): loss=16.841387650436264, w0=71.864863612108, w1=13.81732763123892
# Gradient Descent(37/49): loss=16.463983820209506, w0=73.217477986093, w1=12.958146148195864
# Gradient Descent(38/49): loss=15.524825408381053, w0=73.3928755461106, w1=12.996538655198036
# Gradient Descent(39/49): loss=15.507512221503783, w0=74.28539286623429, w1=13.53033514155395
# Gradient Descent(40/49): loss=15.878676435247833, w0=74.77998143210326, w1=13.120306303920072
# Gradient Descent(41/49): loss=16.554660567097475, w0=71.23349540302101, w1=14.367491897595116
# Gradient Descent(42/49): loss=17.90264294104876, w0=72.29204556258914, w1=14.234884230134826
# Gradient Descent(43/49): loss=16.17290828894993, w0=74.00578133092527, w1=13.316789794519462
# Gradient Descent(44/49): loss=15.652531614232283, w0=73.51071931963749, w1=13.586979178602455
# Gradient Descent(45/49): loss=15.415141484416713, w0=72.54440959821243, w1=12.490372954392637
# Gradient Descent(46/49): loss=16.156168594557343, w0=73.28851147056602, w1=13.804556514316705
# Gradient Descent(47/49): loss=15.438664343692288, w0=74.0217662287627, w1=14.07123268194354
# Gradient Descent(48/49): loss=15.825714579247286, w0=73.67074122018082, w1=12.971200631345726
# Gradient Descent(49/49): loss=15.58617635760726, w0=74.16194473485726, w1=13.962142181936919
# SGD: execution time=0.046 seconds

# %%
# Time Visualization
from ipywidgets import IntSlider, interact
def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        sgd_losses, sgd_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # 5 Effect of Outliers and MAE Cost Function, and Subgradient Descent

# %% [markdown]
# ### Exercise 5
#
# Load and plot data containing outliers

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Modify the function `compute_loss(y, tx, w)` for the Mean Absolute Error cost function [here](#compute_loss)
